# %% [markdown]
# <a href="https://colab.research.google.com/github/Dev-hottae/PINC/blob/master/Mirae_research.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Drive Mount

# from google.colab import drive
# drive.mount("/content/drive")

# %%
# Package

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from dateutil.relativedelta import relativedelta
from datetime import datetime, timedelta

# %%
# change user PATH
user_path = r'C:\Users\dlagh\PycharmProjects\PINC\Mirae_data_research\data_set'

history_path = user_path + '\\trade_train.csv'
stocks_info_path = user_path + '\\stocks_price_history.csv'

# %%
# 데이터 불러오기
stocks_price_history = pd.read_csv(stocks_info_path, encoding='utf-8')
trade_history = pd.read_csv(history_path, encoding='utf-8')

# %%
trade_history
# Out:
#        Unnamed: 0    기준년월   그룹번호  그룹내고객수     종목번호 그룹내_매수여부 그룹내_매도여부  매수고객수  \
# 0               0  201907  MAD01     288  A000660        Y        Y      7
# 1               1  201907  MAD01     288  A001820        Y        Y      3
# 2               2  201907  MAD01     288  A004020        Y        Y      3
# 3               3  201907  MAD01     288  A005380        Y        Y      4
# 4               4  201907  MAD01     288  A005930        Y        Y     13
# ...           ...     ...    ...     ...      ...      ...      ...    ...
# 30195       30195  202006  MAD48     163  A207940        Y        Y      3
# 30196       30196  202006  MAD48     163  A272210        Y        Y      3
# 30197       30197  202006  MAD48     163  A285130        Y        Y      6
# 30198       30198  202006  MAD48     163  A316140        Y        Y      5
# 30199       30199  202006  MAD48     163  A336260        Y        Y      5
#
#        매도고객수  평균매수수량  평균매도수량  매수가격_중앙값  매도가격_중앙값
# 0         17      19     234     74800     78500
# 1          4     533     154     47385     46700
# 2          3     409     528     41411     40000
# 3          3     323     451    140602    140628
# 4         19      34     101     45350     46850
# ...      ...     ...     ...       ...       ...
# 30195      4       3       3    835000    797000
# 30196      3      90      42      9900      8870
# 30197      4     271     162    109100     98000
# 30198      4     386     735     10050      9920
# 30199      4     200     190     34682     34489
#
# [30200 rows x 13 columns]

# %%
# 종목별 누적 매수 고객수 확인
accumul_bid_custom_bycode = trade_history.groupby('종목번호').sum()[['매수고객수','매도고객수']].sort_values(by='매수고객수', ascending=False)
accumul_bid_custom_bycode
# Out:
#          매수고객수  매도고객수
# 종목번호
# A005930  23707  17426
# A000660   8649   8164
# A035720   7395   6416
# A005935   5719   3030
# A005380   5297   4377
# ...        ...    ...
# A038060      3      3
# A091580      0      3
# A290670      0      3
# A078340      0      4
# A037460      0      3
#
# [1066 rows x 2 columns]

# %%
# 종목별 누적 매수 횟수 확인
trade_history['종목번호'].value_counts().to_frame()['종목번호'].value_counts().to_frame().sort_index().plot(kind="bar", figsize=(20,10), rot=45)

# %%
# 매수 종목으로 등장한 횟수 x 회 까지 제외
x = 0
bid_count = trade_history['종목번호'].value_counts().to_frame()
ex_stocks = bid_count[bid_count['종목번호'] <= x].index
ex_stocks

# 제외
trade_history_ex1 = trade_history[~trade_history['종목번호'].isin(ex_stocks)]
trade_history_ex1
# Out:
#        Unnamed: 0    기준년월   그룹번호  그룹내고객수     종목번호 그룹내_매수여부 그룹내_매도여부  매수고객수  \
# 0               0  201907  MAD01     288  A000660        Y        Y      7
# 1               1  201907  MAD01     288  A001820        Y        Y      3
# 2               2  201907  MAD01     288  A004020        Y        Y      3
# 3               3  201907  MAD01     288  A005380        Y        Y      4
# 4               4  201907  MAD01     288  A005930        Y        Y     13
# ...           ...     ...    ...     ...      ...      ...      ...    ...
# 30195       30195  202006  MAD48     163  A207940        Y        Y      3
# 30196       30196  202006  MAD48     163  A272210        Y        Y      3
# 30197       30197  202006  MAD48     163  A285130        Y        Y      6
# 30198       30198  202006  MAD48     163  A316140        Y        Y      5
# 30199       30199  202006  MAD48     163  A336260        Y        Y      5
#
#        매도고객수  평균매수수량  평균매도수량  매수가격_중앙값  매도가격_중앙값
# 0         17      19     234     74800     78500
# 1          4     533     154     47385     46700
# 2          3     409     528     41411     40000
# 3          3     323     451    140602    140628
# 4         19      34     101     45350     46850
# ...      ...     ...     ...       ...       ...
# 30195      4       3       3    835000    797000
# 30196      3      90      42      9900      8870
# 30197      4     271     162    109100     98000
# 30198      4     386     735     10050      9920
# 30199      4     200     190     34682     34489
#
# [30200 rows x 13 columns]

# %%
# 그래프를 위한 merge
graph_merge = trade_history_ex1.merge(stocks_info_stop[['종목번호','종목명']], how='left',left_on='종목번호', right_on="종목번호", suffixes=('', 'x'))
graph_merge
# Out:
#        Unnamed: 0    기준년월   그룹번호  그룹내고객수     종목번호 그룹내_매수여부 그룹내_매도여부  매수고객수  \
# 0               0  201907  MAD01     288  A000660        Y        Y      7
# 1               1  201907  MAD01     288  A001820        Y        Y      3
# 2               2  201907  MAD01     288  A004020        Y        Y      3
# 3               3  201907  MAD01     288  A005380        Y        Y      4
# 4               4  201907  MAD01     288  A005930        Y        Y     13
# ...           ...     ...    ...     ...      ...      ...      ...    ...
# 30195       30195  202006  MAD48     163  A207940        Y        Y      3
# 30196       30196  202006  MAD48     163  A272210        Y        Y      3
# 30197       30197  202006  MAD48     163  A285130        Y        Y      6
# 30198       30198  202006  MAD48     163  A316140        Y        Y      5
# 30199       30199  202006  MAD48     163  A336260        Y        Y      5
#
#        매도고객수  평균매수수량  평균매도수량  매수가격_중앙값  매도가격_중앙값       종목명
# 0         17      19     234     74800     78500    SK하이닉스
# 1          4     533     154     47385     46700     삼화콘덴서
# 2          3     409     528     41411     40000      현대제철
# 3          3     323     451    140602    140628       현대차
# 4         19      34     101     45350     46850      삼성전자
# ...      ...     ...     ...       ...       ...       ...
# 30195      4       3       3    835000    797000  삼성바이오로직스
# 30196      3      90      42      9900      8870     한화시스템
# 30197      4     271     162    109100     98000     SK케미칼
# 30198      4     386     735     10050      9920    우리금융지주
# 30199      4     200     190     34682     34489     두산퓨얼셀
#
# [30200 rows x 14 columns]

# %%
# 그룹 내 매수 변화 1년 그래프
#################### Visual Studio Code 전용 한글 폰트 적용 ###################
font_path = "C:/Windows/Fonts/H2GTRM.TTF"
font_name = fm.FontProperties(fname=font_path).get_name()
mpl.rc('font', family=font_name)
##############################################################################
figure, ((ax1,ax2,ax3),(ax4,ax5,ax6),(ax7,ax8,ax9),(ax10,ax11,ax12)) = plt.subplots(nrows=4, ncols=3)
figure.set_size_inches(18,25)

group = "MAD01"

sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201907)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax1)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201908)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax2)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201909)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax3)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201910)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax4)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201911)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax5)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==201912)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax6)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202001)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax7)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202002)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax8)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202003)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax9)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202004)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax10)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202005)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax11)
sns.barplot(data=graph_merge[(graph_merge['그룹번호']==group) & (graph_merge['기준년월']==202006)].sort_values(by='매수고객수', ascending=False)[:10], x='종목명', y='매수고객수', ax=ax12)


ax1.set(title="201907")
ax2.set(title="201908")
ax3.set(title="201909")
ax4.set(title="201910")
ax5.set(title="201911")
ax6.set(title="201912")
ax7.set(title="202001")
ax8.set(title="202002")
ax9.set(title="202003")
ax10.set(title="202004")
ax11.set(title="202005")
ax12.set(title="202006")

ax1.set_xticklabels(ax1.get_xticklabels(),rotation=45)
ax2.set_xticklabels(ax2.get_xticklabels(),rotation=45)
ax3.set_xticklabels(ax3.get_xticklabels(),rotation=45)
ax4.set_xticklabels(ax4.get_xticklabels(),rotation=45)
ax5.set_xticklabels(ax5.get_xticklabels(),rotation=45)
ax6.set_xticklabels(ax6.get_xticklabels(),rotation=45)
ax7.set_xticklabels(ax7.get_xticklabels(),rotation=45)
ax8.set_xticklabels(ax8.get_xticklabels(),rotation=45)
ax9.set_xticklabels(ax9.get_xticklabels(),rotation=45)
ax10.set_xticklabels(ax10.get_xticklabels(),rotation=45)
ax11.set_xticklabels(ax11.get_xticklabels(),rotation=45)
ax12.set_xticklabels(ax12.get_xticklabels(),rotation=45)
# Out:
# [Text(0, 0, '삼성전자'),
#  Text(0, 0, 'SK하이닉스'),
#  Text(0, 0, '삼성전자우'),
#  Text(0, 0, '삼성SDI'),
#  Text(0, 0, 'LG전자'),
#  Text(0, 0, '삼성전기'),
#  Text(0, 0, '현대차'),
#  Text(0, 0, '빅텍'),
#  Text(0, 0, '삼성중공업'),
#  Text(0, 0, '카카오')]

# %%
# trade_history = trade_history[trade_history['매수고객수']>0]
# trade_history

# %%
# 그룹 내에서 거래가 1회 이상인 종목
traded_stocks = trade_history_ex1['종목번호'].unique()
len(traded_stocks)
# Out:
# 1066

# %%
stocks_price_history
# Out:
#          index      기준일자     종목번호       종목명 20년7월TOP3대상여부 시장구분 표준산업구분코드_대분류  \
# 0            0  20190701  A000020      동화약품             N  코스피          제조업
# 1            1  20190701  A000080     하이트진로             N  코스피          제조업
# 2            2  20190701  A000100      유한양행             Y  코스피          제조업
# 3            3  20190701  A000120    CJ대한통운             N  코스피     운수 및 창고업
# 4            4  20190701  A000140  하이트진로홀딩스             Y  코스피     금융 및 보험업
# ...        ...       ...      ...       ...           ...  ...          ...
# 286056  286056  20200728  A336370     두산솔루스             N  코스피          제조업
# 286057  286057  20200728  A33637K   두산솔루스1우             N  코스피          제조업
# 286058  286058  20200728  A33637L  두산솔루스2우B             N  코스피          제조업
# 286059  286059  20200728  A344820   케이씨씨글라스             N  코스피          제조업
# 286060  286060  20200728  A353810     이지바이오             Y  코스닥          제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류    종목시가    종목고가    종목저가    종목종가  \
# 0       의료용 물질 및 의약품 제조업            의약품 제조업    9680    9840    9680    9710
# 1                 음료 제조업          알코올음료 제조업   20550   20550   20200   20300
# 2       의료용 물질 및 의약품 제조업            의약품 제조업  259000  267500  250000  251500
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업  136500  137000  133000  136000
# 4                    금융업             기타 금융업    9060    9190    8910    9000
# ...                  ...                ...     ...     ...     ...     ...
# 286056          통신장비 제조업           전자부품 제조업   37050   39150   37000   38150
# 286057          통신장비 제조업           전자부품 제조업   18100   19350   17950   18250
# 286058          통신장비 제조업           전자부품 제조업   37000   38650   36500   37700
# 286059      비금속 광물제품 제조업      유리 및 유리제품 제조업   33500   33500   32250   32400
# 286060           식료품 제조업  동물용 사료 및 조제식품 제조업   58900   60300   57400   57500
#
#             거래량  거래금액_만원단위
# 0         31341      30581
# 1        127186     258535
# 2        395757   10139357
# 3         62513     846100
# 4          7661       6896
# ...         ...        ...
# 286056  1764085    6755086
# 286057   302925     565624
# 286058    59460     224214
# 286059    56962     186549
# 286060    76761     450070
#
# [286061 rows x 15 columns]

# %%
f_stock_price_history = stocks_price_history[stocks_price_history['종목번호'].isin(traded_stocks)]
f_stock_price_history
# Out:
#          index      기준일자     종목번호       종목명 20년7월TOP3대상여부 시장구분 표준산업구분코드_대분류  \
# 0            0  20190701  A000020      동화약품             N  코스피          제조업
# 1            1  20190701  A000080     하이트진로             N  코스피          제조업
# 2            2  20190701  A000100      유한양행             Y  코스피          제조업
# 3            3  20190701  A000120    CJ대한통운             N  코스피     운수 및 창고업
# 4            4  20190701  A000140  하이트진로홀딩스             Y  코스피     금융 및 보험업
# ...        ...       ...      ...       ...           ...  ...          ...
# 286056  286056  20200728  A336370     두산솔루스             N  코스피          제조업
# 286057  286057  20200728  A33637K   두산솔루스1우             N  코스피          제조업
# 286058  286058  20200728  A33637L  두산솔루스2우B             N  코스피          제조업
# 286059  286059  20200728  A344820   케이씨씨글라스             N  코스피          제조업
# 286060  286060  20200728  A353810     이지바이오             Y  코스닥          제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류    종목시가    종목고가    종목저가    종목종가  \
# 0       의료용 물질 및 의약품 제조업            의약품 제조업    9680    9840    9680    9710
# 1                 음료 제조업          알코올음료 제조업   20550   20550   20200   20300
# 2       의료용 물질 및 의약품 제조업            의약품 제조업  259000  267500  250000  251500
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업  136500  137000  133000  136000
# 4                    금융업             기타 금융업    9060    9190    8910    9000
# ...                  ...                ...     ...     ...     ...     ...
# 286056          통신장비 제조업           전자부품 제조업   37050   39150   37000   38150
# 286057          통신장비 제조업           전자부품 제조업   18100   19350   17950   18250
# 286058          통신장비 제조업           전자부품 제조업   37000   38650   36500   37700
# 286059      비금속 광물제품 제조업      유리 및 유리제품 제조업   33500   33500   32250   32400
# 286060           식료품 제조업  동물용 사료 및 조제식품 제조업   58900   60300   57400   57500
#
#             거래량  거래금액_만원단위
# 0         31341      30581
# 1        127186     258535
# 2        395757   10139357
# 3         62513     846100
# 4          7661       6896
# ...         ...        ...
# 286056  1764085    6755086
# 286057   302925     565624
# 286058    59460     224214
# 286059    56962     186549
# 286060    76761     450070
#
# [280165 rows x 15 columns]

# %%
# 종목 info
stocks_info = f_stock_price_history.drop_duplicates(subset=['종목번호'])[['종목번호','종목명','20년7월TOP3대상여부','시장구분','표준산업구분코드_대분류','표준산업구분코드_중분류','표준산업구분코드_소분류']]
stocks_info
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분      표준산업구분코드_대분류  \
# 0       A000020      동화약품             N  코스피               제조업
# 1       A000080     하이트진로             N  코스피               제조업
# 2       A000100      유한양행             Y  코스피               제조업
# 3       A000120    CJ대한통운             N  코스피          운수 및 창고업
# 4       A000140  하이트진로홀딩스             Y  코스피          금융 및 보험업
# ...         ...       ...           ...  ...               ...
# 183938  A237820      플레이디             N  코스닥  전문· 과학 및 기술 서비스업
# 186020  A198080       엔피디             N  코스닥               제조업
# 245858  A353810     이지바이오             Y  코스닥               제조업
# 254499  A298060  에스씨엠생명과학             N  코스닥               제조업
# 257755  A297890       엘이티             N  코스닥               제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류
# 0       의료용 물질 및 의약품 제조업            의약품 제조업
# 1                 음료 제조업          알코올음료 제조업
# 2       의료용 물질 및 의약품 제조업            의약품 제조업
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업
# 4                    금융업             기타 금융업
# ...                  ...                ...
# 183938            전문서비스업                광고업
# 186020          통신장비 제조업           전자부품 제조업
# 245858           식료품 제조업  동물용 사료 및 조제식품 제조업
# 254499  의료용 물질 및 의약품 제조업            의약품 제조업
# 257755    기타 기계 및 장비 제조업      특수 목적용 기계 제조업
#
# [1065 rows x 7 columns]

# %%
# # 데이터 저장
# f_stock_price_history.to_csv("traded_stocks_info.csv")

# %%
stop_data = f_stock_price_history[f_stock_price_history['거래량']==0]['종목명'].value_counts().to_frame()
stop_data
# Out:
#            종목명
# 셀루메드       175
# 럭슬         118
# 내츄럴엔도텍     113
# 경남제약       108
# 포티스         94
# ...        ...
# 한화우          1
# 루미마이크로       1
# 셀바스헬스케어      1
# 에이치엘비생명과학    1
# 체시스          1
#
# [93 rows x 1 columns]

# %%
# 거래정지 원인 파악을 위한
f_stock_price_history[(f_stock_price_history['종목명']=="흥아해운") & (f_stock_price_history['거래량']==0)]
# Out:
#          index      기준일자     종목번호   종목명 20년7월TOP3대상여부 시장구분 표준산업구분코드_대분류  \
# 196059  196059  20200330  A003280  흥아해운             N  코스피     운수 및 창고업
# 197143  197143  20200331  A003280  흥아해운             N  코스피     운수 및 창고업
# 198227  198227  20200401  A003280  흥아해운             N  코스피     운수 및 창고업
# 199311  199311  20200402  A003280  흥아해운             N  코스피     운수 및 창고업
# 200395  200395  20200403  A003280  흥아해운             N  코스피     운수 및 창고업
# ...        ...       ...      ...   ...           ...  ...          ...
# 280691  280691  20200722  A003280  흥아해운             N  코스피     운수 및 창고업
# 281778  281778  20200723  A003280  흥아해운             N  코스피     운수 및 창고업
# 282865  282865  20200724  A003280  흥아해운             N  코스피     운수 및 창고업
# 283952  283952  20200727  A003280  흥아해운             N  코스피     운수 및 창고업
# 285039  285039  20200728  A003280  흥아해운             N  코스피     운수 및 창고업
#
#        표준산업구분코드_중분류 표준산업구분코드_소분류  종목시가  종목고가  종목저가  종목종가  거래량  거래금액_만원단위
# 196059       수상 운송업       해상 운송업     0     0     0   258    0          0
# 197143       수상 운송업       해상 운송업     0     0     0   258    0          0
# 198227       수상 운송업       해상 운송업     0     0     0   258    0          0
# 199311       수상 운송업       해상 운송업     0     0     0   258    0          0
# 200395       수상 운송업       해상 운송업     0     0     0   258    0          0
# ...             ...          ...   ...   ...   ...   ...  ...        ...
# 280691       수상 운송업       해상 운송업     0     0     0   258    0          0
# 281778       수상 운송업       해상 운송업     0     0     0   258    0          0
# 282865       수상 운송업       해상 운송업     0     0     0   258    0          0
# 283952       수상 운송업       해상 운송업     0     0     0   258    0          0
# 285039       수상 운송업       해상 운송업     0     0     0   258    0          0
#
# [83 rows x 15 columns]

# %%
# 거래정지횟수 데이터 추가
stocks_info_stop = stocks_info.merge(stop_data, how='left',left_on='종목명', right_index=True, suffixes=('', 'x')).rename(columns={'종목명x':'정지이력'})
stocks_info_stop['정지이력'].fillna(value=0, inplace=True)
stocks_info_stop
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분      표준산업구분코드_대분류  \
# 0       A000020      동화약품             N  코스피               제조업
# 1       A000080     하이트진로             N  코스피               제조업
# 2       A000100      유한양행             Y  코스피               제조업
# 3       A000120    CJ대한통운             N  코스피          운수 및 창고업
# 4       A000140  하이트진로홀딩스             Y  코스피          금융 및 보험업
# ...         ...       ...           ...  ...               ...
# 183938  A237820      플레이디             N  코스닥  전문· 과학 및 기술 서비스업
# 186020  A198080       엔피디             N  코스닥               제조업
# 245858  A353810     이지바이오             Y  코스닥               제조업
# 254499  A298060  에스씨엠생명과학             N  코스닥               제조업
# 257755  A297890       엘이티             N  코스닥               제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류  정지이력
# 0       의료용 물질 및 의약품 제조업            의약품 제조업   0.0
# 1                 음료 제조업          알코올음료 제조업   0.0
# 2       의료용 물질 및 의약품 제조업            의약품 제조업   3.0
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업   0.0
# 4                    금융업             기타 금융업   0.0
# ...                  ...                ...   ...
# 183938            전문서비스업                광고업   0.0
# 186020          통신장비 제조업           전자부품 제조업   0.0
# 245858           식료품 제조업  동물용 사료 및 조제식품 제조업   2.0
# 254499  의료용 물질 및 의약품 제조업            의약품 제조업   0.0
# 257755    기타 기계 및 장비 제조업      특수 목적용 기계 제조업   0.0
#
# [1065 rows x 8 columns]

# %%
# Y 항목중 거래정지이력 있는애들
stocks_info_stop[(stocks_info_stop['20년7월TOP3대상여부']=="Y") & (stocks_info_stop['정지이력']>0)]
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분 표준산업구분코드_대분류  \
# 2       A000100      유한양행             Y  코스피          제조업
# 17      A000885       한화우             Y  코스피          제조업
# 147     A008060        대덕             Y  코스피          제조업
# 181     A010145     삼성중공우             Y  코스피          제조업
# 220     A014100      메디앙스             Y  코스닥          제조업
# 256     A019170      신풍제약             Y  코스피          제조업
# 335     A033250       체시스             Y  코스피          제조업
# 511     A058110    멕아이씨에스             Y  코스닥          제조업
# 555     A066430      와이오엠             Y  코스닥     도매 및 소매업
# 724     A102940   코오롱생명과학             Y  코스닥          제조업
# 742     A114120      크루셜텍             Y  코스닥          제조업
# 763     A123010  아이에이네트웍스             Y  코스닥          제조업
# 794     A139050   데일리블록체인             Y  코스닥        정보통신업
# 798     A141020       포티스             Y  코스닥     도매 및 소매업
# 854     A195440        퓨전             Y  코스닥        정보통신업
# 245858  A353810     이지바이오             Y  코스닥          제조업
#
#                    표준산업구분코드_중분류             표준산업구분코드_소분류  정지이력
# 2              의료용 물질 및 의약품 제조업                  의약품 제조업   3.0
# 17                       의약품 제외              기타 화학제품 제조업   1.0
# 147                    통신장비 제조업                 전자부품 제조업  14.0
# 181                 기타 운송장비 제조업              선박 및 보트 건조업   3.0
# 220                      의약품 제외              기타 화학제품 제조업  89.0
# 256            의료용 물질 및 의약품 제조업                  의약품 제조업   4.0
# 335              자동차 및 트레일러 제조업            자동차 신품 부품 제조업   1.0
# 511       의료· 정밀· 광학기기 및 시계 제조업               의료용 기기 제조업   3.0
# 555                 도매 및 상품 중개업                기타 전문 도매업   1.0
# 724            의료용 물질 및 의약품 제조업    기초 의약물질 및 생물학적 제제 제조업   1.0
# 742                    통신장비 제조업                 전자부품 제조업  12.0
# 763                    통신장비 제조업                 전자부품 제조업  11.0
# 794     컴퓨터 프로그래밍· 시스템 통합 및 관리업  컴퓨터 프로그래밍· 시스템 통합 및 관리업   1.0
# 798                 소매업; 자동차 제외                  무점포 소매업  94.0
# 854                         출판업           소프트웨어 개발 및 공급업  92.0
# 245858                  식료품 제조업        동물용 사료 및 조제식품 제조업   2.0

# %%
from datetime import datetime
import pandas as pd
import numpy as np
from datetime import datetime
from matplotlib import font_manager as fm, rc
import matplotlib as mpl
import matplotlib.pyplot as plt
# 필요 함수 세팅

# 그룹과 일자 input 시 매수많이 일어난 top 추출함수
def which_is_top(group, date, top):
    data = trade_history[(trade_history['기준년월'] == date) & (trade_history['그룹번호'] == ("MAD"+group))]
    data = data.sort_values(by=["매수고객수"],ascending=False)
    data = data[data['매수고객수'] > 0][:top]

    data = data.merge(stocks_info, how="inner", on="종목번호")
    return data

# 종목명으로 종목코드 가져오기
def code_by_name(name):
    return stocks_info.loc[stocks_info['종목명'] == name]

# 종목코드로 종목명 가져오기
def name_by_code(code):
    return stocks_info.loc[stocks_info['종목번호'] == code]

def get_std(code, start_month, end_month):
    print(code)
    stocks_price_history['기준일자'] = pd.to_datetime(stocks_price_history['기준일자'], format="%Y%m%d")

    start = start_month
    end = end_month

    # 지정종목, 기간 데이터 추출
    data = stocks_price_history[(stocks_price_history['종목번호'] == code) & (stocks_price_history['기준일자'] >= start) & (stocks_price_history['기준일자'] < end)]

    # 거래량 0 제거
    data = data[data['거래량'] > 0]
    print("데이터 갯수 : ",len(data))
    if len(data) == 0:
        stdrate_year = None
    else:
        year = 252
        avg = data['종목종가'].mean()
        std_day = (data['종목종가'].std()/avg)/np.sqrt(len(data))
        stdrate_year = std_day * np.sqrt(year) * 100
        print(data['종목명'].tolist()[0], stdrate_year)

    return stdrate_year

# 종목 모멘텀 구하기
def get_momentom(code, start_month, end_month):
    print(code)
    stocks_price_history['기준일자'] = pd.to_datetime(stocks_price_history['기준일자'], format="%Y%m%d")

    start = start_month
    end = end_month

    # 지정종목, 기간 데이터 추출
    data = stocks_price_history[(stocks_price_history['종목번호'] == code) & (stocks_price_history['기준일자'] >= start) & (
                stocks_price_history['기준일자'] < end)]

    # 거래량 0 제거
#     data = data[data['거래량'] > 0]
    if (len(data) == 0):
        mom = None
    else:
        close_prices = data['종목종가'].tolist()
        # print(close_prices)
        mom = np.log(close_prices[-1]/close_prices[0])*100
        print(data['종목명'].tolist()[0], mom)
    return mom

# 가격변화률 구하기
def get_change_rate(code, start_month, end_month):
    print(code)
    stocks_price_history['기준일자'] = pd.to_datetime(stocks_price_history['기준일자'], format="%Y%m%d")

    start = start_month
    end = end_month

    # 지정종목, 기간 데이터 추출
    data = stocks_price_history[(stocks_price_history['종목번호'] == code) & (stocks_price_history['기준일자'] >= start) & (
                stocks_price_history['기준일자'] < end)]
    if(len(data)==0):
        return None
    else:
        start_price = data['종목종가'].tolist()[0]
        lowest_price = data['종목종가'].min()
        highest_price = data['종목종가'].max()

        # , np.log(highest_price/start_price)*100
        return np.log(lowest_price/start_price)*100

# %%
stocks_info = stocks_info_stop
stocks_info
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분      표준산업구분코드_대분류  \
# 0       A000020      동화약품             N  코스피               제조업
# 1       A000080     하이트진로             N  코스피               제조업
# 2       A000100      유한양행             Y  코스피               제조업
# 3       A000120    CJ대한통운             N  코스피          운수 및 창고업
# 4       A000140  하이트진로홀딩스             Y  코스피          금융 및 보험업
# ...         ...       ...           ...  ...               ...
# 183938  A237820      플레이디             N  코스닥  전문· 과학 및 기술 서비스업
# 186020  A198080       엔피디             N  코스닥               제조업
# 245858  A353810     이지바이오             Y  코스닥               제조업
# 254499  A298060  에스씨엠생명과학             N  코스닥               제조업
# 257755  A297890       엘이티             N  코스닥               제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류  정지이력
# 0       의료용 물질 및 의약품 제조업            의약품 제조업   0.0
# 1                 음료 제조업          알코올음료 제조업   0.0
# 2       의료용 물질 및 의약품 제조업            의약품 제조업   3.0
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업   0.0
# 4                    금융업             기타 금융업   0.0
# ...                  ...                ...   ...
# 183938            전문서비스업                광고업   0.0
# 186020          통신장비 제조업           전자부품 제조업   0.0
# 245858           식료품 제조업  동물용 사료 및 조제식품 제조업   2.0
# 254499  의료용 물질 및 의약품 제조업            의약품 제조업   0.0
# 257755    기타 기계 및 장비 제조업      특수 목적용 기계 제조업   0.0
#
# [1065 rows x 8 columns]

# %%
# stocks_info['변동성_현월'] = 0
# stocks_info['변동성_전월'] = 0

# stocks_info['모멘텀_1'] = 0
# stocks_info['모멘텀_3'] = 0

stocks_info['최고상승율_현월'] = 0
stocks_info['최고하락율_현월'] = 0
stocks_info['최고상승율_전월'] = 0
stocks_info['최고하락율_전월'] = 0

stocks_info
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분      표준산업구분코드_대분류  \
# 0       A000020      동화약품             N  코스피               제조업
# 1       A000080     하이트진로             N  코스피               제조업
# 2       A000100      유한양행             Y  코스피               제조업
# 3       A000120    CJ대한통운             N  코스피          운수 및 창고업
# 4       A000140  하이트진로홀딩스             Y  코스피          금융 및 보험업
# ...         ...       ...           ...  ...               ...
# 183938  A237820      플레이디             N  코스닥  전문· 과학 및 기술 서비스업
# 186020  A198080       엔피디             N  코스닥               제조업
# 245858  A353810     이지바이오             Y  코스닥               제조업
# 254499  A298060  에스씨엠생명과학             N  코스닥               제조업
# 257755  A297890       엘이티             N  코스닥               제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류  정지이력     변동성_현월     변동성_전월  \
# 0       의료용 물질 및 의약품 제조업            의약품 제조업   0.0   9.192805   6.325298
# 1                 음료 제조업          알코올음료 제조업   0.0   7.131278   7.010732
# 2       의료용 물질 및 의약품 제조업            의약품 제조업   3.0  15.925354   2.924712
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업   0.0   4.959833   4.907247
# 4                    금융업             기타 금융업   0.0   8.045202  10.135311
# ...                  ...                ...   ...        ...        ...
# 183938            전문서비스업                광고업   0.0        NaN        NaN
# 186020          통신장비 제조업           전자부품 제조업   0.0        NaN        NaN
# 245858           식료품 제조업  동물용 사료 및 조제식품 제조업   2.0        NaN        NaN
# 254499  의료용 물질 및 의약품 제조업            의약품 제조업   0.0        NaN        NaN
# 257755    기타 기계 및 장비 제조업      특수 목적용 기계 제조업   0.0        NaN        NaN
#
#            모멘텀_1      모멘텀_3  최고상승율_현월  최고하락율_현월  최고상승율_전월  최고하락율_전월
# 0       2.436174   2.559555         0         0         0         0
# 1       4.225981   5.492966         0         0         0         0
# 2       9.066980   3.004518         0         0         0         0
# 3       0.647251   8.408312         0         0         0         0
# 4       2.687302  16.877733         0         0         0         0
# ...          ...        ...       ...       ...       ...       ...
# 183938       NaN        NaN         0         0         0         0
# 186020       NaN        NaN         0         0         0         0
# 245858       NaN        NaN         0         0         0         0
# 254499       NaN        NaN         0         0         0         0
# 257755       NaN        NaN         0         0         0         0
#
# [1065 rows x 16 columns]

# %%
# 종목체크
stocks_price_history[stocks_price_history['종목명']=="흥아해운"]
# Out:
#          index      기준일자     종목번호   종목명 20년7월TOP3대상여부 시장구분 표준산업구분코드_대분류  \
# 65          65  20190701  A003280  흥아해운             N  코스피     운수 및 창고업
# 1092      1092  20190702  A003280  흥아해운             N  코스피     운수 및 창고업
# 2119      2119  20190703  A003280  흥아해운             N  코스피     운수 및 창고업
# 3146      3146  20190704  A003280  흥아해운             N  코스피     운수 및 창고업
# 4173      4173  20190705  A003280  흥아해운             N  코스피     운수 및 창고업
# ...        ...       ...      ...   ...           ...  ...          ...
# 280691  280691  20200722  A003280  흥아해운             N  코스피     운수 및 창고업
# 281778  281778  20200723  A003280  흥아해운             N  코스피     운수 및 창고업
# 282865  282865  20200724  A003280  흥아해운             N  코스피     운수 및 창고업
# 283952  283952  20200727  A003280  흥아해운             N  코스피     운수 및 창고업
# 285039  285039  20200728  A003280  흥아해운             N  코스피     운수 및 창고업
#
#        표준산업구분코드_중분류 표준산업구분코드_소분류  종목시가  종목고가  종목저가  종목종가      거래량  거래금액_만원단위
# 65           수상 운송업       해상 운송업   610   666   605   620  2104918     132857
# 1092         수상 운송업       해상 운송업   620   620   609   612   693009      42483
# 2119         수상 운송업       해상 운송업   619   620   600   604   708560      43082
# 3146         수상 운송업       해상 운송업   604   606   589   592   724354      43122
# 4173         수상 운송업       해상 운송업   599   601   583   592   613155      36072
# ...             ...          ...   ...   ...   ...   ...      ...        ...
# 280691       수상 운송업       해상 운송업     0     0     0   258        0          0
# 281778       수상 운송업       해상 운송업     0     0     0   258        0          0
# 282865       수상 운송업       해상 운송업     0     0     0   258        0          0
# 283952       수상 운송업       해상 운송업     0     0     0   258        0          0
# 285039       수상 운송업       해상 운송업     0     0     0   258        0          0
#
# [268 rows x 15 columns]

# %%
target_date = 202001
check_date = 201912
start = datetime.strptime(str(check_date), '%Y%m')
end = datetime.strptime(str(target_date), '%Y%m')

# stocks_info['변동성_현월'] = stocks_info['종목번호'].apply(lambda x: get_std(x, start, end))
# stocks_info['변동성_전월'] = stocks_info['종목번호'].apply(lambda x: get_std(x, start-relativedelta(months=+1), end-relativedelta(months=+1)))

# stocks_info['모멘텀_1'] = stocks_info['종목번호'].apply(lambda x: get_momentom(x, start, end))
# stocks_info['모멘텀_3'] = stocks_info['종목번호'].apply(lambda x: get_momentom(x, start-relativedelta(months=+2), end))

stocks_info['최고하락율_현월'] = stocks_info['종목번호'].apply(lambda x: get_change_rate(x, start, end))
stocks_info['최고하락율_전월'] = stocks_info['종목번호'].apply(lambda x: get_change_rate(x, start-relativedelta(months=+1), end-relativedelta(months=+1)))
# Out:
# A000020
# A000080
# A000100
# A000120
# A000140
# A000145
# A000150
# A000210
# A000220
# A000250
# A000270
# A000440
# A000520
# A000660
# A000720
# A000810
# A000880
# A000885
# A000890
# A000910
# A000990
# A001000
# A001040
# A001060
# A001120
# A001140
# A001200
# A001210
# A001230
# A001260
# A001340
# A001360
# A001440
# A001510
# A001520
# A001540
# A001550
# A001680
# A001740
# A001820
# A001840
# A002020
# A002070
# A002100
# A002140
# A002210
# A002320
# A002360
# A002410
# A002630
# A002700
# A002720
# A002760
# A002780
# A002790
# A002800
# A002900
# A003000
# A003010
# A003060
# A003090
# A003220
# A003230
# A003280
# A003350
# A003410
# A003490
# A003495
# A003520
# A003550
# A003560
# A003620
# A003670
# A003680
# A003850
# A004020
# A004060
# A004100
# A004140
# A004170
# A004270
# A004310
# A004370
# A004410
# A004430
# A004540
# A004650
# A004710
# A004720
# A004770
# A004800
# A004830
# A004835
# A004870
# A004980
# A004990
# A00499K
# A005070
# A005110
# A005180
# A005290
# A005320
# A005360
# A005380
# A005385
# A005390
# A005420
# A005490
# A005500
# A005690
# A005860
# A005870
# A005930
# A005935
# A005940
# A005950
# A006050
# A006060
# A006090
# A006120
# A006125
# A006280
# A006360
# A006400
# A006405
# A006490
# A006620
# A006800
# A00680K
# A006890
# A006910
# A006980
# A007070
# A007110
# A007210
# A007370
# A007390
# A007460
# A007540
# A007570
# A007660
# A007700
# A007810
# A007860
# A007980
# A008060
# A008290
# A008350
# A008355
# A008420
# A008560
# A008600
# A008700
# A008730
# A008770
# A008930
# A008970
# A009150
# A009180
# A009190
# A009240
# A009270
# A009290
# A009320
# A009420
# A009450
# A009460
# A009470
# A009520
# A009540
# A009620
# A009730
# A009810
# A009830
# A010040
# A010060
# A010100
# A010130
# A010140
# A010145
# A010170
# A010280
# A010600
# A010620
# A010660
# A010820
# A010950
# A011000
# A011040
# A011070
# A011150
# A011170
# A011200
# A011210
# A011280
# A011320
# A011390
# A011780
# A011790
# A011930
# A012200
# A012280
# A012330
# A012450
# A012510
# A012610
# A012630
# A012690
# A012700
# A012790
# A012800
# A012860
# A013000
# A013310
# A013700
# A013810
# A013990
# A014100
# A014130
# A014160
# A014190
# A014470
# A014530
# A014570
# A014580
# A014970
# A014990
# A015590
# A015760
# A015860
# A016360
# A016600
# A016670
# A016740
# A016790
# A016880
# A016920
# A017180
# A017550
# A017650
# A017670
# A017800
# A017810
# A017890
# A017960
# A018000
# A018250
# A018260
# A018290
# A018620
# A018680
# A018700
# A018880
# A019170
# A019175
# A019540
# A019770
# A020120
# A020150
# A020180
# A020560
# A021050
# A021240
# A021880
# A022100
# A023150
# A023410
# A023530
# A023590
# A023770
# A023900
# A024060
# A024110
# A024740
# A024810
# A024900
# A024950
# A025320
# A025440
# A025560
# A025620
# A025770
# A025820
# A025870
# A025900
# A026150
# A026890
# A026940
# A027050
# A027360
# A027580
# A027710
# A027740
# A027830
# A028050
# A028100
# A028260
# A028300
# A028670
# A029960
# A030000
# A030190
# A030200
# A030350
# A030520
# A030530
# A030790
# A030960
# A031310
# A031330
# A031390
# A031430
# A031820
# A031860
# A032190
# A032500
# A032580
# A032620
# A032640
# A032680
# A032800
# A032820
# A032830
# A032850
# A032980
# A033050
# A033130
# A033170
# A033180
# A033230
# A033250
# A033270
# A033320
# A033340
# A033430
# A033500
# A033600
# A033640
# A033830
# A034020
# A034220
# A034230
# A034730
# A03473K
# A034940
# A035250
# A035420
# A035600
# A035620
# A035720
# A035760
# A035810
# A035890
# A035900
# A036030
# A036120
# A036170
# A036180
# A036200
# A036420
# A036460
# A036480
# A036490
# A036540
# A036570
# A036630
# A036640
# A036810
# A036830
# A036930
# A037030
# A037070
# A037230
# A037270
# A037330
# A037460
# A037560
# A037950
# A038060
# A038070
# A038160
# A038290
# A038340
# A038500
# A038530
# A038540
# A038680
# A038870
# A039030
# A039130
# A039200
# A039230
# A039440
# A039560
# A039610
# A039830
# A039860
# A040350
# A040910
# A041140
# A041190
# A041460
# A041510
# A041590
# A041830
# A041910
# A041920
# A041930
# A041960
# A042000
# A042040
# A042500
# A042510
# A042520
# A042660
# A042670
# A042700
# A043200
# A043220
# A043340
# A043610
# A043910
# A044340
# A044380
# A044480
# A044960
# A045060
# A045390
# A045520
# A045660
# A045890
# A046440
# A046890
# A046940
# A046970
# A047040
# A047050
# A047310
# A047400
# A047770
# A047810
# A047820
# A047920
# A048260
# A048410
# A048430
# A048530
# A048550
# A049080
# A049180
# A049480
# A049830
# A050110
# A050120
# A050890
# A051160
# A051370
# A051380
# A051600
# A051780
# A051900
# A051910
# A051915
# A052020
# A052190
# A052260
# A052300
# A052420
# A052460
# A052600
# A052670
# A052710
# A052860
# A052900
# A053030
# A053110
# A053290
# A053300
# A053590
# A053610
# A053660
# A053800
# A053950
# A053980
# A054090
# A054210
# A054300
# A054450
# A054620
# A054630
# A054670
# A054780
# A054940
# A055550
# A056000
# A056190
# A056360
# A056700
# A057030
# A057500
# A057540
# A057880
# A058110
# A058400
# A058530
# A058630
# A058820
# A059090
# A060150
# A060240
# A060250
# A060260
# A060310
# A060370
# A060480
# A060570
# A060590
# A060720
# A061040
# A061250
# A061970
# A062970
# A063160
# A063440
# A063570
# A064240
# A064260
# A064290
# A064350
# A064510
# A064550
# A064800
# A064820
# A065060
# A065130
# A065170
# A065440
# A065450
# A065530
# A065620
# A065650
# A065660
# A065950
# A066130
# A066360
# A066410
# A066430
# A066570
# A066590
# A066700
# A066910
# A066970
# A067000
# A067010
# A067080
# A067160
# A067170
# A067290
# A067310
# A067390
# A067570
# A067630
# A067900
# A067990
# A068240
# A068270
# A068290
# A068330
# A068760
# A069080
# A069460
# A069620
# A071050
# A071200
# A071970
# A072020
# A072130
# A072470
# A072520
# A072870
# A073070
# A073110
# A073490
# A073540
# A073560
# A074600
# A074610
# A075970
# A077360
# A077500
# A078070
# A078130
# A078150
# A078160
# A078340
# A078520
# A078590
# A078600
# A078890
# A078930
# A079160
# A079550
# A079940
# A079970
# A079980
# A080160
# A080220
# A080720
# A081000
# A081150
# A081660
# A082210
# A082270
# A082740
# A082800
# A083310
# A083450
# A083500
# A083550
# A083640
# A083790
# A084370
# A084650
# A084680
# A084870
# A084990
# A085660
# A086040
# A086060
# A086250
# A086280
# A086390
# A086520
# A086670
# A086790
# A086820
# A086890
# A086900
# A086980
# A087010
# A087260
# A087730
# A088290
# A088350
# A088800
# A088910
# A089010
# A089030
# A089150
# A089590
# A089980
# A090080
# A090360
# A090410
# A090430
# A090460
# A090710
# A091340
# A091580
# A091590
# A091700
# A091810
# A091970
# A091990
# A092040
# A092190
# A092600
# A093230
# A093320
# A093370
# A093380
# A094170
# A094360
# A094940
# A095190
# A095340
# A095500
# A095610
# A095660
# A095700
# A095720
# A096040
# A096350
# A096530
# A096610
# A096630
# A096760
# A096770
# A097230
# A097520
# A097780
# A097800
# A097950
# A098120
# A098460
# A099220
# A099410
# A099440
# A100120
# A100130
# A100220
# A100590
# A100660
# A101160
# A101490
# A102120
# A102280
# A102460
# A102710
# A102940
# A103140
# A104040
# A104480
# A104830
# A105560
# A105840
# A106240
# A108230
# A108320
# A108490
# A109820
# A109960
# A111710
# A111870
# A112040
# A112610
# A114090
# A114120
# A114450
# A115180
# A115390
# A115440
# A115450
# A115480
# A115500
# A117670
# A118000
# A118990
# A119500
# A119650
# A119860
# A120110
# A120240
# A121800
# A122310
# A122350
# A122870
# A122990
# A123010
# A123040
# A123410
# A123420
# A123690
# A124500
# A125210
# A126560
# A126640
# A126880
# A127160
# A128940
# A130500
# A131090
# A131370
# A131390
# A131760
# A131970
# A133750
# A133820
# A136480
# A136510
# A136540
# A137400
# A137940
# A137950
# A138080
# A138490
# A138610
# A139050
# A139130
# A139480
# A140410
# A141020
# A141070
# A141080
# A142280
# A142760
# A143160
# A143540
# A144510
# A144620
# A144960
# A145020
# A147760
# A150840
# A151860
# A153710
# A159580
# A160550
# A160600
# A160980
# A161390
# A161580
# A161890
# A166090
# A166480
# A168330
# A170030
# A171010
# A171090
# A174880
# A174900
# A175250
# A177350
# A177830
# A178320
# A178920
# A179290
# A179900
# A180640
# A18064K
# A181710
# A182360
# A182400
# A183490
# A185490
# A185750
# A187420
# A189300
# A190510
# A191420
# A192080
# A192250
# A192440
# A192650
# A192820
# A193250
# A194700
# A195440
# A195990
# A196170
# A196450
# A196490
# A198440
# A200130
# A200230
# A200670
# A200710
# A200780
# A201490
# A203650
# A203690
# A204020
# A204320
# A204840
# A205100
# A205470
# A205500
# A206560
# A206640
# A206650
# A207760
# A207940
# A208140
# A208340
# A208350
# A208370
# A213420
# A214150
# A214180
# A214270
# A214310
# A214330
# A214420
# A214430
# A214680
# A214870
# A215090
# A215100
# A215360
# A215380
# A215480
# A215600
# A215790
# A217330
# A217480
# A217500
# A217600
# A217730
# A218150
# A218410
# A219130
# A219420
# A219550
# A220260
# A220630
# A221610
# A222080
# A222420
# A222800
# A222810
# A222980
# A223310
# A224060
# A225430
# A225570
# A226360
# A226440
# A226950
# A228760
# A230240
# A230360
# A234080
# A234100
# A236200
# A237690
# A237880
# A238090
# A238120
# A238490
# A239340
# A240810
# A241560
# A241790
# A241820
# A242040
# A243070
# A243840
# A245620
# A246690
# A246710
# A247540
# A248170
# A249420
# A250000
# A250060
# A251270
# A252500
# A253450
# A253840
# A255440
# A256630
# A256840
# A256940
# A257370
# A258610
# A260660
# A263050
# A263540
# A263600
# A263690
# A263700
# A263720
# A263750
# A263770
# A263800
# A263920
# A264450
# A264660
# A265520
# A265560
# A267250
# A267260
# A267270
# A267790
# A267850
# A268600
# A270870
# A271560
# A271980
# A272290
# A272450
# A278280
# A281740
# A281820
# A284620
# A285130
# A28513K
# A285490
# A288620
# A289080
# A290270
# A290380
# A290550
# A290650
# A290660
# A290670
# A290740
# A293780
# A294870
# A298040
# A298050
# A298380
# A298690
# A299660
# A299900
# A302430
# A302550
# A303030
# A305090
# A307930
# A308100
# A312610
# A316140
# A317320
# A319660
# A289010
# A234340
# A300080
# A241840
# A317850
# A313760
# A148150
# A318000
# A317330
# A282880
# A228670
# A317830
# A286750
# A195500
# A311390
# A256150
# A317120
# A244460
# A234690
# A158430
# A300120
# A336260
# A33626K
# A33626L
# A336370
# A33637K
# A33637L
# A318010
# A317870
# A272110
# A317530
# A322180
# A084850
# A214260
# A272210
# A216080
# A322000
# A103840
# A190650
# A297090
# A321550
# A308170
# A278650
# A290510
# A124560
# A322510
# A226330
# A235980
# A288330
# A327260
# A344820
# A294630
# A294140
# A274090
# A204270
# A237820
# A198080
# A353810
# A298060
# A297890
# A000020
# A000080
# A000100
# A000120
# A000140
# A000145
# A000150
# A000210
# A000220
# A000250
# A000270
# A000440
# A000520
# A000660
# A000720
# A000810
# A000880
# A000885
# A000890
# A000910
# A000990
# A001000
# A001040
# A001060
# A001120
# A001140
# A001200
# A001210
# A001230
# A001260
# A001340
# A001360
# A001440
# A001510
# A001520
# A001540
# A001550
# A001680
# A001740
# A001820
# A001840
# A002020
# A002070
# A002100
# A002140
# A002210
# A002320
# A002360
# A002410
# A002630
# A002700
# A002720
# A002760
# A002780
# A002790
# A002800
# A002900
# A003000
# A003010
# A003060
# A003090
# A003220
# A003230
# A003280
# A003350
# A003410
# A003490
# A003495
# A003520
# A003550
# A003560
# A003620
# A003670
# A003680
# A003850
# A004020
# A004060
# A004100
# A004140
# A004170
# A004270
# A004310
# A004370
# A004410
# A004430
# A004540
# A004650
# A004710
# A004720
# A004770
# A004800
# A004830
# A004835
# A004870
# A004980
# A004990
# A00499K
# A005070
# A005110
# A005180
# A005290
# A005320
# A005360
# A005380
# A005385
# A005390
# A005420
# A005490
# A005500
# A005690
# A005860
# A005870
# A005930
# A005935
# A005940
# A005950
# A006050
# A006060
# A006090
# A006120
# A006125
# A006280
# A006360
# A006400
# A006405
# A006490
# A006620
# A006800
# A00680K
# A006890
# A006910
# A006980
# A007070
# A007110
# A007210
# A007370
# A007390
# A007460
# A007540
# A007570
# A007660
# A007700
# A007810
# A007860
# A007980
# A008060
# A008290
# A008350
# A008355
# A008420
# A008560
# A008600
# A008700
# A008730
# A008770
# A008930
# A008970
# A009150
# A009180
# A009190
# A009240
# A009270
# A009290
# A009320
# A009420
# A009450
# A009460
# A009470
# A009520
# A009540
# A009620
# A009730
# A009810
# A009830
# A010040
# A010060
# A010100
# A010130
# A010140
# A010145
# A010170
# A010280
# A010600
# A010620
# A010660
# A010820
# A010950
# A011000
# A011040
# A011070
# A011150
# A011170
# A011200
# A011210
# A011280
# A011320
# A011390
# A011780
# A011790
# A011930
# A012200
# A012280
# A012330
# A012450
# A012510
# A012610
# A012630
# A012690
# A012700
# A012790
# A012800
# A012860
# A013000
# A013310
# A013700
# A013810
# A013990
# A014100
# A014130
# A014160
# A014190
# A014470
# A014530
# A014570
# A014580
# A014970
# A014990
# A015590
# A015760
# A015860
# A016360
# A016600
# A016670
# A016740
# A016790
# A016880
# A016920
# A017180
# A017550
# A017650
# A017670
# A017800
# A017810
# A017890
# A017960
# A018000
# A018250
# A018260
# A018290
# A018620
# A018680
# A018700
# A018880
# A019170
# A019175
# A019540
# A019770
# A020120
# A020150
# A020180
# A020560
# A021050
# A021240
# A021880
# A022100
# A023150
# A023410
# A023530
# A023590
# A023770
# A023900
# A024060
# A024110
# A024740
# A024810
# A024900
# A024950
# A025320
# A025440
# A025560
# A025620
# A025770
# A025820
# A025870
# A025900
# A026150
# A026890
# A026940
# A027050
# A027360
# A027580
# A027710
# A027740
# A027830
# A028050
# A028100
# A028260
# A028300
# A028670
# A029960
# A030000
# A030190
# A030200
# A030350
# A030520
# A030530
# A030790
# A030960
# A031310
# A031330
# A031390
# A031430
# A031820
# A031860
# A032190
# A032500
# A032580
# A032620
# A032640
# A032680
# A032800
# A032820
# A032830
# A032850
# A032980
# A033050
# A033130
# A033170
# A033180
# A033230
# A033250
# A033270
# A033320
# A033340
# A033430
# A033500
# A033600
# A033640
# A033830
# A034020
# A034220
# A034230
# A034730
# A03473K
# A034940
# A035250
# A035420
# A035600
# A035620
# A035720
# A035760
# A035810
# A035890
# A035900
# A036030
# A036120
# A036170
# A036180
# A036200
# A036420
# A036460
# A036480
# A036490
# A036540
# A036570
# A036630
# A036640
# A036810
# A036830
# A036930
# A037030
# A037070
# A037230
# A037270
# A037330
# A037460
# A037560
# A037950
# A038060
# A038070
# A038160
# A038290
# A038340
# A038500
# A038530
# A038540
# A038680
# A038870
# A039030
# A039130
# A039200
# A039230
# A039440
# A039560
# A039610
# A039830
# A039860
# A040350
# A040910
# A041140
# A041190
# A041460
# A041510
# A041590
# A041830
# A041910
# A041920
# A041930
# A041960
# A042000
# A042040
# A042500
# A042510
# A042520
# A042660
# A042670
# A042700
# A043200
# A043220
# A043340
# A043610
# A043910
# A044340
# A044380
# A044480
# A044960
# A045060
# A045390
# A045520
# A045660
# A045890
# A046440
# A046890
# A046940
# A046970
# A047040
# A047050
# A047310
# A047400
# A047770
# A047810
# A047820
# A047920
# A048260
# A048410
# A048430
# A048530
# A048550
# A049080
# A049180
# A049480
# A049830
# A050110
# A050120
# A050890
# A051160
# A051370
# A051380
# A051600
# A051780
# A051900
# A051910
# A051915
# A052020
# A052190
# A052260
# A052300
# A052420
# A052460
# A052600
# A052670
# A052710
# A052860
# A052900
# A053030
# A053110
# A053290
# A053300
# A053590
# A053610
# A053660
# A053800
# A053950
# A053980
# A054090
# A054210
# A054300
# A054450
# A054620
# A054630
# A054670
# A054780
# A054940
# A055550
# A056000
# A056190
# A056360
# A056700
# A057030
# A057500
# A057540
# A057880
# A058110
# A058400
# A058530
# A058630
# A058820
# A059090
# A060150
# A060240
# A060250
# A060260
# A060310
# A060370
# A060480
# A060570
# A060590
# A060720
# A061040
# A061250
# A061970
# A062970
# A063160
# A063440
# A063570
# A064240
# A064260
# A064290
# A064350
# A064510
# A064550
# A064800
# A064820
# A065060
# A065130
# A065170
# A065440
# A065450
# A065530
# A065620
# A065650
# A065660
# A065950
# A066130
# A066360
# A066410
# A066430
# A066570
# A066590
# A066700
# A066910
# A066970
# A067000
# A067010
# A067080
# A067160
# A067170
# A067290
# A067310
# A067390
# A067570
# A067630
# A067900
# A067990
# A068240
# A068270
# A068290
# A068330
# A068760
# A069080
# A069460
# A069620
# A071050
# A071200
# A071970
# A072020
# A072130
# A072470
# A072520
# A072870
# A073070
# A073110
# A073490
# A073540
# A073560
# A074600
# A074610
# A075970
# A077360
# A077500
# A078070
# A078130
# A078150
# A078160
# A078340
# A078520
# A078590
# A078600
# A078890
# A078930
# A079160
# A079550
# A079940
# A079970
# A079980
# A080160
# A080220
# A080720
# A081000
# A081150
# A081660
# A082210
# A082270
# A082740
# A082800
# A083310
# A083450
# A083500
# A083550
# A083640
# A083790
# A084370
# A084650
# A084680
# A084870
# A084990
# A085660
# A086040
# A086060
# A086250
# A086280
# A086390
# A086520
# A086670
# A086790
# A086820
# A086890
# A086900
# A086980
# A087010
# A087260
# A087730
# A088290
# A088350
# A088800
# A088910
# A089010
# A089030
# A089150
# A089590
# A089980
# A090080
# A090360
# A090410
# A090430
# A090460
# A090710
# A091340
# A091580
# A091590
# A091700
# A091810
# A091970
# A091990
# A092040
# A092190
# A092600
# A093230
# A093320
# A093370
# A093380
# A094170
# A094360
# A094940
# A095190
# A095340
# A095500
# A095610
# A095660
# A095700
# A095720
# A096040
# A096350
# A096530
# A096610
# A096630
# A096760
# A096770
# A097230
# A097520
# A097780
# A097800
# A097950
# A098120
# A098460
# A099220
# A099410
# A099440
# A100120
# A100130
# A100220
# A100590
# A100660
# A101160
# A101490
# A102120
# A102280
# A102460
# A102710
# A102940
# A103140
# A104040
# A104480
# A104830
# A105560
# A105840
# A106240
# A108230
# A108320
# A108490
# A109820
# A109960
# A111710
# A111870
# A112040
# A112610
# A114090
# A114120
# A114450
# A115180
# A115390
# A115440
# A115450
# A115480
# A115500
# A117670
# A118000
# A118990
# A119500
# A119650
# A119860
# A120110
# A120240
# A121800
# A122310
# A122350
# A122870
# A122990
# A123010
# A123040
# A123410
# A123420
# A123690
# A124500
# A125210
# A126560
# A126640
# A126880
# A127160
# A128940
# A130500
# A131090
# A131370
# A131390
# A131760
# A131970
# A133750
# A133820
# A136480
# A136510
# A136540
# A137400
# A137940
# A137950
# A138080
# A138490
# A138610
# A139050
# A139130
# A139480
# A140410
# A141020
# A141070
# A141080
# A142280
# A142760
# A143160
# A143540
# A144510
# A144620
# A144960
# A145020
# A147760
# A150840
# A151860
# A153710
# A159580
# A160550
# A160600
# A160980
# A161390
# A161580
# A161890
# A166090
# A166480
# A168330
# A170030
# A171010
# A171090
# A174880
# A174900
# A175250
# A177350
# A177830
# A178320
# A178920
# A179290
# A179900
# A180640
# A18064K
# A181710
# A182360
# A182400
# A183490
# A185490
# A185750
# A187420
# A189300
# A190510
# A191420
# A192080
# A192250
# A192440
# A192650
# A192820
# A193250
# A194700
# A195440
# A195990
# A196170
# A196450
# A196490
# A198440
# A200130
# A200230
# A200670
# A200710
# A200780
# A201490
# A203650
# A203690
# A204020
# A204320
# A204840
# A205100
# A205470
# A205500
# A206560
# A206640
# A206650
# A207760
# A207940
# A208140
# A208340
# A208350
# A208370
# A213420
# A214150
# A214180
# A214270
# A214310
# A214330
# A214420
# A214430
# A214680
# A214870
# A215090
# A215100
# A215360
# A215380
# A215480
# A215600
# A215790
# A217330
# A217480
# A217500
# A217600
# A217730
# A218150
# A218410
# A219130
# A219420
# A219550
# A220260
# A220630
# A221610
# A222080
# A222420
# A222800
# A222810
# A222980
# A223310
# A224060
# A225430
# A225570
# A226360
# A226440
# A226950
# A228760
# A230240
# A230360
# A234080
# A234100
# A236200
# A237690
# A237880
# A238090
# A238120
# A238490
# A239340
# A240810
# A241560
# A241790
# A241820
# A242040
# A243070
# A243840
# A245620
# A246690
# A246710
# A247540
# A248170
# A249420
# A250000
# A250060
# A251270
# A252500
# A253450
# A253840
# A255440
# A256630
# A256840
# A256940
# A257370
# A258610
# A260660
# A263050
# A263540
# A263600
# A263690
# A263700
# A263720
# A263750
# A263770
# A263800
# A263920
# A264450
# A264660
# A265520
# A265560
# A267250
# A267260
# A267270
# A267790
# A267850
# A268600
# A270870
# A271560
# A271980
# A272290
# A272450
# A278280
# A281740
# A281820
# A284620
# A285130
# A28513K
# A285490
# A288620
# A289080
# A290270
# A290380
# A290550
# A290650
# A290660
# A290670
# A290740
# A293780
# A294870
# A298040
# A298050
# A298380
# A298690
# A299660
# A299900
# A302430
# A302550
# A303030
# A305090
# A307930
# A308100
# A312610
# A316140
# A317320
# A319660
# A289010
# A234340
# A300080
# A241840
# A317850
# A313760
# A148150
# A318000
# A317330
# A282880
# A228670
# A317830
# A286750
# A195500
# A311390
# A256150
# A317120
# A244460
# A234690
# A158430
# A300120
# A336260
# A33626K
# A33626L
# A336370
# A33637K
# A33637L
# A318010
# A317870
# A272110
# A317530
# A322180
# A084850
# A214260
# A272210
# A216080
# A322000
# A103840
# A190650
# A297090
# A321550
# A308170
# A278650
# A290510
# A124560
# A322510
# A226330
# A235980
# A288330
# A327260
# A344820
# A294630
# A294140
# A274090
# A204270
# A237820
# A198080
# A353810
# A298060
# A297890

# %%
# stocks_info.drop(columns=['최고상승률_현월', '최고하락율_현월','최고상승률_전월','최고하락율_전월'], inplace=True)

# %%
stocks_info
# Out:
#            종목번호       종목명 20년7월TOP3대상여부 시장구분      표준산업구분코드_대분류  \
# 0       A000020      동화약품             N  코스피               제조업
# 1       A000080     하이트진로             N  코스피               제조업
# 2       A000100      유한양행             Y  코스피               제조업
# 3       A000120    CJ대한통운             N  코스피          운수 및 창고업
# 4       A000140  하이트진로홀딩스             Y  코스피          금융 및 보험업
# ...         ...       ...           ...  ...               ...
# 183938  A237820      플레이디             N  코스닥  전문· 과학 및 기술 서비스업
# 186020  A198080       엔피디             N  코스닥               제조업
# 245858  A353810     이지바이오             Y  코스닥               제조업
# 254499  A298060  에스씨엠생명과학             N  코스닥               제조업
# 257755  A297890       엘이티             N  코스닥               제조업
#
#             표준산업구분코드_중분류       표준산업구분코드_소분류  정지이력     변동성_현월     변동성_전월  \
# 0       의료용 물질 및 의약품 제조업            의약품 제조업   0.0   9.192805   6.325298
# 1                 음료 제조업          알코올음료 제조업   0.0   7.131278   7.010732
# 2       의료용 물질 및 의약품 제조업            의약품 제조업   3.0  15.925354   2.924712
# 3       육상운송 및 파이프라인 운송업          도로 화물 운송업   0.0   4.959833   4.907247
# 4                    금융업             기타 금융업   0.0   8.045202  10.135311
# ...                  ...                ...   ...        ...        ...
# 183938            전문서비스업                광고업   0.0        NaN        NaN
# 186020          통신장비 제조업           전자부품 제조업   0.0        NaN        NaN
# 245858           식료품 제조업  동물용 사료 및 조제식품 제조업   2.0        NaN        NaN
# 254499  의료용 물질 및 의약품 제조업            의약품 제조업   0.0        NaN        NaN
# 257755    기타 기계 및 장비 제조업      특수 목적용 기계 제조업   0.0        NaN        NaN
#
#            모멘텀_1      모멘텀_3   최고상승율_현월  최고하락율_현월  최고상승율_전월  최고하락율_전월
# 0       2.436174   2.559555   2.436174 -6.758467  7.438372  0.000000
# 1       4.225981   5.492966   4.398246 -2.734902  4.497011 -3.819909
# 2       9.066980   3.004518  13.005313 -0.231750  0.681047 -2.537622
# 3       0.647251   8.408312   1.929320 -3.300630  4.652002 -0.317965
# 4       2.687302  16.877733   2.687302 -4.781787  4.930576 -5.949710
# ...          ...        ...        ...       ...       ...       ...
# 183938       NaN        NaN        NaN       NaN       NaN       NaN
# 186020       NaN        NaN        NaN       NaN       NaN       NaN
# 245858       NaN        NaN        NaN       NaN       NaN       NaN
# 254499       NaN        NaN        NaN       NaN       NaN       NaN
# 257755       NaN        NaN        NaN       NaN       NaN       NaN
#
# [1065 rows x 16 columns]

# %%
# None 데이터 종합
stocks_info.isnull().sum()
# Out:
# 종목번호              0
# 종목명               0
# 20년7월TOP3대상여부     0
# 시장구분              0
# 표준산업구분코드_대분류      0
# 표준산업구분코드_중분류      0
# 표준산업구분코드_소분류      0
# 정지이력              0
# 변동성_현월           12
# 변동성_전월           19
# 모멘텀_1            10
# 모멘텀_3            10
# 최고상승율_현월         10
# 최고하락율_현월         10
# 최고상승율_전월         16
# 최고하락율_전월         16
# dtype: int64

# %%
# 재무정보 로드
fin_data_path = r'C:\Users\dlagh\Downloads\재무정보.csv'

# %%
fin_data = pd.read_csv(fin_data_path, encoding='utf-8')
fin_data
# Out:
#         종목번호       상장주식수 201906_매출 201909_매출 201912_매출 202003_매출 202006_매출  \
# 0     000020  27,931,470       749       742       833       670       698
# 1     000080  70,133,611      5244      5291      5586      5339      5816
# 2     000100  66,856,810      3594      3823      3937      3133      4155
# 3     000120  22,812,344     25348     26218     28257     25154     26500
# 4     000140  23,206,765      5221      5267      5566      5315      5797
# ...      ...         ...       ...       ...       ...       ...       ...
# 1082  237820  12,827,140       NaN        88        86        77        72
# 1083  198080  21,535,185       NaN       799       718       641       406
# 1084  353810   2,286,728       NaN       NaN       NaN       NaN       215
# 1085  298060  11,858,116       NaN       NaN       NaN         -         1
# 1086  297890   7,109,450       NaN       NaN       NaN        41        50
#
#      201906_영업이익 201909_영업이익 201912_영업이익  ... 201906_당기순이익 201909_당기순이익  \
# 0             -9           7          78  ...           -6            2
# 1            106         492         327  ...         -292          258
# 2            -54          33          85  ...           57          126
# 3            718         887        1013  ...          176          130
# 4            148         518         353  ...         -306          235
# ...          ...         ...         ...  ...          ...          ...
# 1082         NaN          15          19  ...          NaN           11
# 1083         NaN          86          57  ...          NaN           72
# 1084         NaN         NaN         NaN  ...          NaN          NaN
# 1085         NaN         NaN         NaN  ...          NaN          NaN
# 1086         NaN         NaN         NaN  ...          NaN          NaN
#
#      201912_당기순이익 202003_당기순이익 202006_당기순이익 201906_부채비율 201909_부채비율  \
# 0              79           23           67       27.83       27.42
# 1            -252          334          349      216.79      209.50
# 2              27         1154          343       28.13       29.48
# 3             328          114          362      158.94      159.02
# 4            -166          279          369      288.38      280.42
# ...           ...          ...          ...         ...         ...
# 1082           15            5            1         NaN      122.35
# 1083           21           10            5         NaN      294.96
# 1084          NaN          NaN           28         NaN         NaN
# 1085          NaN          -39         -104         NaN         NaN
# 1086          NaN            -            2         NaN         NaN
#
#       201912_부채비율  202003_부채비율  202006_부채비율
# 0           24.98        25.61        24.78
# 1          216.58       256.41       305.21
# 2           28.32        29.92        32.64
# 3          149.23       154.80       153.73
# 4          290.48       327.01       377.81
# ...           ...          ...          ...
# 1082       140.76        64.29        52.63
# 1083       254.37       141.20       108.36
# 1084          NaN          NaN       198.39
# 1085          NaN        79.99        18.12
# 1086          NaN        62.04        41.16
#
# [1087 rows x 22 columns]

# %%
# 직전분기 재무정보가져오기
# 종목번호 앞에 A 붙이기
fin_data['종목번호'] = "A"+fin_data['종목번호']
# Out:
#          종목번호       상장주식수 201906_매출 201909_매출 201912_매출 202003_매출 202006_매출  \
# 0     A000020  27,931,470       749       742       833       670       698
# 1     A000080  70,133,611      5244      5291      5586      5339      5816
# 2     A000100  66,856,810      3594      3823      3937      3133      4155
# 3     A000120  22,812,344     25348     26218     28257     25154     26500
# 4     A000140  23,206,765      5221      5267      5566      5315      5797
# ...       ...         ...       ...       ...       ...       ...       ...
# 1082  A237820  12,827,140       NaN        88        86        77        72
# 1083  A198080  21,535,185       NaN       799       718       641       406
# 1084  A353810   2,286,728       NaN       NaN       NaN       NaN       215
# 1085  A298060  11,858,116       NaN       NaN       NaN         -         1
# 1086  A297890   7,109,450       NaN       NaN       NaN        41        50
#
#      201906_영업이익 201909_영업이익 201912_영업이익  ... 201906_당기순이익 201909_당기순이익  \
# 0             -9           7          78  ...           -6            2
# 1            106         492         327  ...         -292          258
# 2            -54          33          85  ...           57          126
# 3            718         887        1013  ...          176          130
# 4            148         518         353  ...         -306          235
# ...          ...         ...         ...  ...          ...          ...
# 1082         NaN          15          19  ...          NaN           11
# 1083         NaN          86          57  ...          NaN           72
# 1084         NaN         NaN         NaN  ...          NaN          NaN
# 1085         NaN         NaN         NaN  ...          NaN          NaN
# 1086         NaN         NaN         NaN  ...          NaN          NaN
#
#      201912_당기순이익 202003_당기순이익 202006_당기순이익 201906_부채비율 201909_부채비율  \
# 0              79           23           67       27.83       27.42
# 1            -252          334          349      216.79      209.50
# 2              27         1154          343       28.13       29.48
# 3             328          114          362      158.94      159.02
# 4            -166          279          369      288.38      280.42
# ...           ...          ...          ...         ...         ...
# 1082           15            5            1         NaN      122.35
# 1083           21           10            5         NaN      294.96
# 1084          NaN          NaN           28         NaN         NaN
# 1085          NaN          -39         -104         NaN         NaN
# 1086          NaN            -            2         NaN         NaN
#
#       201912_부채비율  202003_부채비율  202006_부채비율
# 0           24.98        25.61        24.78
# 1          216.58       256.41       305.21
# 2           28.32        29.92        32.64
# 3          149.23       154.80       153.73
# 4          290.48       327.01       377.81
# ...           ...          ...          ...
# 1082       140.76        64.29        52.63
# 1083       254.37       141.20       108.36
# 1084          NaN          NaN       198.39
# 1085          NaN        79.99        18.12
# 1086          NaN        62.04        41.16
#
# [1087 rows x 22 columns]

# %%
fin_data['201906_매출'].isna().sum()
# Out:
# 49

# %%
drop_fin_data = fin_data.dropna()
drop_fin_data
# Out:
#         종목번호       상장주식수 201906_매출 201909_매출 201912_매출 202003_매출 202006_매출  \
# 0     000020  27,931,470       749       742       833       670       698
# 1     000080  70,133,611      5244      5291      5586      5339      5816
# 2     000100  66,856,810      3594      3823      3937      3133      4155
# 3     000120  22,812,344     25348     26218     28257     25154     26500
# 4     000140  23,206,765      5221      5267      5566      5315      5797
# ...      ...         ...       ...       ...       ...       ...       ...
# 1044  244460  15,969,001         1         3         9        16         9
# 1055  317870   7,485,555        27        27        18        22        22
# 1060  214260   8,416,416        48        54        36        58        33
# 1073  226330  13,242,016         1         1         1         1         1
# 1079  294140  34,500,000       102       151       122       143       477
#
#      201906_영업이익 201909_영업이익 201912_영업이익  ... 201906_당기순이익 201909_당기순이익  \
# 0             -9           7          78  ...           -6            2
# 1            106         492         327  ...         -292          258
# 2            -54          33          85  ...           57          126
# 3            718         887        1013  ...          176          130
# 4            148         518         353  ...         -306          235
# ...          ...         ...         ...  ...          ...          ...
# 1044         -37         -59         -60  ...          -33          -84
# 1055           5           5          -3  ...            -            5
# 1060           4           7         -16  ...            7           10
# 1073         -15         -14         -15  ...         -195          -13
# 1079         -48          -8         -12  ...          -47          -14
#
#      201912_당기순이익 202003_당기순이익 202006_당기순이익 201906_부채비율 201909_부채비율  \
# 0              79           23           67       27.83       27.42
# 1            -252          334          349      216.79      209.50
# 2              27         1154          343       28.13       29.48
# 3             328          114          362      158.94      159.02
# 4            -166          279          369      288.38      280.42
# ...           ...          ...          ...         ...         ...
# 1044         -290          -64          -74     -262.05      123.48
# 1055           -1           -1            1       90.73       83.86
# 1060          -16            9          -25       59.73       96.69
# 1073          -14          -13          -17        4.88        5.91
# 1079          -21            -          205      144.35      209.88
#
#       201912_부채비율  202003_부채비율  202006_부채비율
# 0           24.98        25.61        24.78
# 1          216.58       256.41       305.21
# 2           28.32        29.92        32.64
# 3          149.23       154.80       153.73
# 4          290.48       327.01       377.81
# ...           ...          ...          ...
# 1044       191.28       285.28       633.68
# 1055        39.85        39.29        30.24
# 1060        31.20        30.79        32.74
# 1073         3.98         4.26         6.68
# 1079       419.46       163.45        74.58
#
# [1031 rows x 22 columns]
